# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from MITRotor import BEM, IEA10MW, BEMGeometry, NoTipLoss, ConstantInduction, KraghAerodynamics, ClassicalMomentum, UnifiedMomentum, MadsenMomentum, NoTangentialInduction, BEMSolution

# %%
fontsize = 24
plt.rcParams['xtick.labelsize'] = 20 
plt.rcParams['ytick.labelsize'] = 20 

plt.rcParams.update({
    'text.usetex': True,
    'text.latex.preamble': r'\usepackage{amsfonts}'
})

# %%
# Initialize rotor with increased radial resolution.
rotor = IEA10MW()

ClassMom = BEM(rotor=rotor, geometry=BEMGeometry(Nr=99, Ntheta=360), aerodynamic_model=KraghAerodynamics(), tiploss_model=NoTipLoss(), momentum_model=ClassicalMomentum(), tangential_induction_model=NoTangentialInduction())

ConstInd = BEM(rotor=rotor, geometry=BEMGeometry(Nr=99, Ntheta=360), aerodynamic_model=KraghAerodynamics(), tiploss_model=NoTipLoss(), momentum_model=ConstantInduction(), tangential_induction_model=NoTangentialInduction())

MadseMom = BEM(rotor=rotor, geometry=BEMGeometry(Nr=99, Ntheta=360), aerodynamic_model=KraghAerodynamics(), tiploss_model=NoTipLoss(), momentum_model=MadsenMomentum(), tangential_induction_model=NoTangentialInduction())

UnifiMom = BEM(rotor=rotor, geometry=BEMGeometry(Nr=99, Ntheta=360), aerodynamic_model=KraghAerodynamics(), tiploss_model=NoTipLoss(), momentum_model=UnifiedMomentum(), tangential_induction_model=NoTangentialInduction())

# %% [markdown]
# # IEA 10 MW

# %%
from MITRotor import IEA10MW

# %%
nElements = 26
nSections = 158

# %%
ws_pow = np.array([4.10,4.20,4.30,4.40,4.50,4.60,4.70,4.80,4.90,5.00,5.10,5.20,5.30,5.40,5.50,5.60,5.70,5.80,5.90,6.00,6.10,6.20,6.30,6.40,6.50,6.60,6.70,6.80,6.90,7.00,7.10,7.20,7.30,7.40,7.50,7.60,7.70,7.80,7.90,8.00,8.10,8.20,8.30,8.40,8.50,8.60,8.70,8.80,8.90,9.00,9.10,9.20,9.30,9.40,9.50,9.60,9.70,9.80,9.90,10.00,10.10,10.20,10.30,10.40,10.50,10.60,10.70,10.80,10.90,11.00,11.10,11.20,11.30,11.40,11.50,11.60,11.70,11.80,11.90,12.00,12.10,12.20,12.30,12.40,12.50,12.60,12.70,12.80,12.90,13.00,13.10,13.20,13.30,13.40,13.50,13.60,13.70,13.80,13.90,14.00,14.10,14.20,14.30,14.40,14.50,14.60,14.70,14.80,14.90,15.00,15.10,15.20,15.30,15.40,15.50,15.60,15.70,15.80,15.90,16.00,16.10,16.20,16.30,16.40,16.50,16.60,16.70,16.80,16.90,17.00,17.10,17.20,17.30,17.40,17.50,17.60,17.70,17.80,17.90,18.00,18.10,18.20,18.30,18.40,18.50,18.60,18.70,18.80,18.90,19.00,19.10,19.20,19.30,19.40,19.50,19.60,19.70,19.80,19.90,20.00,20.10,20.20,20.30,20.40,20.50,20.60,20.70,20.80,20.90,21.00,21.10,21.20,21.30,21.40,21.50,21.60,21.70,21.80,21.90,22.00,22.10,22.20,22.30,22.40,22.50,22.60,22.70,22.80,22.90,23.00,23.10,23.20,23.30,23.40,23.50,23.60,23.70,23.80,23.90,24.00,24.10,24.20,24.30,24.40,24.50,24.60,24.70,24.80,24.90])
rpm    = np.array([6,6,6.123, 7.144, 8.165, 8.684, 8.684, 8.684, 8.684, 8.684, 8.684, 8.684, 8.684, 8.684, 8.684, 8.684, 8.684, 8.684, 8.684])

ws_pit = np.array([4,5,6,7,8,9,0.5, 10, 10.5, 11, 11.5, 12, 13, 14, 15, 16, 18, 20, 25])
pitch  = np.array([2.589,1.355,0,0,0,0,0,0,0,2.633,4.537,5.975,8.250,10.121,11.771,13.280,16.018,18.513,24.110])

# %%
f_rpm = interp1d(ws_rpm, rpm, kind='linear')
f_pit = interp1d(ws_pit, pitch, kind='linear')

# %%
ws_ref = np.linspace(6, 25, 50)

# %%
ClassMom_cot = np.zeros_like(ws_ref)
ClassMom_cop = np.zeros_like(ws_ref)
ClassMom_P   = np.zeros_like(ws_ref)
ClassMom_T   = np.zeros_like(ws_ref)

ConstInd_cot = np.zeros_like(ws_ref)
ConstInd_cop = np.zeros_like(ws_ref)
ConstInd_P   = np.zeros_like(ws_ref)
ConstInd_T   = np.zeros_like(ws_ref)

MadseMom_cot = np.zeros_like(ws_ref)
MadseMom_cop = np.zeros_like(ws_ref)
MadseMom_P   = np.zeros_like(ws_ref)
MadseMom_T   = np.zeros_like(ws_ref)

UnifiMom_cot = np.zeros_like(ws_ref)
UnifiMom_cop = np.zeros_like(ws_ref)
UnifiMom_P   = np.zeros_like(ws_ref)
UnifiMom_T   = np.zeros_like(ws_ref)

# %%
for i in range(len(ws_ref)):
    pitch, tsr, yaw = np.deg2rad(f_pit(ws_ref[i])), f_rpm(ws_ref[i]) * 2 * np.pi * rotor.R / 60 / ws_ref[i], np.deg2rad(0.0)
    ClassMomSol = ClassMom(pitch, tsr, yaw, v_inf=ws_ref[i])
    ConstIndSol = ConstInd(pitch, tsr, yaw, v_inf=ws_ref[i])
    MadseMomSol = MadseMom(pitch, tsr, yaw, v_inf=ws_ref[i])
    UnifiMomSol = UnifiMom(pitch, tsr, yaw, v_inf=ws_ref[i])

    # print('Classical Momentum')
    ClassMom_cot[i] = ClassMomSol.Ct()
    ClassMom_cop[i] = ClassMomSol.Cp()
    ClassMom_P[i]   = ClassMomSol.power()
    ClassMom_T[i]   = ClassMomSol.thrust()

    # print('Constant Induction')
    ConstInd_cot[i] = ConstIndSol.Ct()
    ConstInd_cop[i] = ConstIndSol.Cp()
    ConstInd_P[i]   = ConstIndSol.power()
    ConstInd_T[i]   = ConstIndSol.thrust()

    # print('Madsen Momentum')
    MadseMom_cot[i] = MadseMomSol.Ct()
    MadseMom_cop[i] = MadseMomSol.Cp()
    MadseMom_P[i]   = MadseMomSol.power()
    MadseMom_T[i]   = MadseMomSol.thrust()

    UnifiMom_cot[i] = UnifiMomSol.Ct()
    UnifiMom_cop[i] = UnifiMomSol.Cp()
    UnifiMom_P[i]   = UnifiMomSol.power()
    UnifiMom_T[i]   = UnifiMomSol.thrust()
# Out:
# /home1/09909/smata/miniconda3/envs/mitrotor/lib/python3.10/site-packages/UnifiedMomentumModel/Momentum.py:109: RuntimeWarning: invalid value encountered in sqrt
#   e_a = 1 - np.sqrt(1 - u4**2 - v4**2) / (np.sqrt(Ctprime) * np.cos(yaw)) - a
# /home1/09909/smata/miniconda3/envs/mitrotor/lib/python3.10/site-packages/UnifiedMomentumModel/Utilities/FixedPointIteration.py:56: RuntimeWarning: All-NaN axis encountered
#   max_resid = [np.nanmax(np.abs(_r)) for _r in residuals]

# %%
fig, ax = plt.subplots(2, 2, figsize=(18, 9), sharex=True)

ax[0,0].set_ylabel('Thrust [kN]')
# ax[0,0].plot(ws_ref, ConstInd_cot*0.5*1.225*np.pi*(rotor.R**2)*(ws_ref**2)/1000, color=sns.color_palette()[0], label='Constant Induction ($a=1/3$)')
ax[0,0].plot(ws_ref, ClassMom_T/1000, color=sns.color_palette()[2], label='Classical Momentum')
ax[0,0].plot(ws_ref, MadseMom_T/1000, color=sns.color_palette()[3], label='Madsen Momentum')
ax[0,0].plot(ws_ref, UnifiMom_T/1000, color=sns.color_palette()[4], label='Unified Momentum')
ax[0,0].plot(ws_thr, thrust, 'grey', label='Reference')
ax[0,0].legend(loc='upper right', framealpha=1)
ax[0,0].set_ylim([0,3000])
ax[0,0].set_xlim([0,25])
ax[0,0].grid(True,color = "grey", linewidth = "0.25")

ax[0,1].set_ylabel('Power [kW]')
# ax[0,1].plot(ws_ref, ConstInd_cop*0.5*1.225*np.pi*(rotor.R**2)*(ws_ref**3)/1000, color=sns.color_palette()[0], label='Constant Induction ($a=1/3$)')
ax[0,1].plot(ws_ref, ClassMom_P/1000, color=sns.color_palette()[2], label='Classical Momentum')
ax[0,1].plot(ws_ref, MadseMom_P/1000, color=sns.color_palette()[3], label='Madsen Momentum')
ax[0,1].plot(ws_ref, UnifiMom_P/1000, color=sns.color_palette()[4], label='Unified Momentum')
# ax[0,1].plot(ws_cop, cop*0.5*1.225*np.pi*(rotor.R**2)*(ws_cop**3)/1000, color='green', label='test')
# ax[0,1].plot(ws_cop, (cop+0.01)*0.5*1.225*np.pi*(rotor.R**2)*(ws_cop**3)/1000, color='brown', label='test')
ax[0,1].plot(ws_pow, power, 'grey', label='Reference')
ax[0,1].set_ylim([0,27000])
ax[0,1].grid(True,color = "grey", linewidth = "0.25")

ax[1,0].set_ylabel('$C_T$ [-]')
# ax[1,0].plot(ws_ref, ConstInd_cot, color=sns.color_palette()[0], label='Constant Induction ($a=1/3$)')
ax[1,0].plot(ws_ref, ClassMom_cot, color=sns.color_palette()[2], label='Classical Momentum')
ax[1,0].plot(ws_ref, MadseMom_cot, color=sns.color_palette()[3], label='Madsen Momentum')
ax[1,0].plot(ws_ref, UnifiMom_cot, color=sns.color_palette()[4], label='Unified Momentum')
ax[1,0].plot(ws_cot, cot, 'grey')
# ax[1,0].legend()
ax[1,0].set_ylim([0,1.05])
ax[1,0].grid(True,color = "grey", linewidth = "0.25")

ax[1,1].set_ylabel('$C_P$ [-]')
# ax[1,1].plot(ws_ref, ConstInd_cop, color=sns.color_palette()[0], label='Constant Induction ($a=1/3$)')
ax[1,1].plot(ws_ref, ClassMom_cop, color=sns.color_palette()[2], label='Classical Momentum')
ax[1,1].plot(ws_ref, MadseMom_cop, color=sns.color_palette()[3], label='Madsen Momentum')
ax[1,1].plot(ws_ref, UnifiMom_cop, color=sns.color_palette()[4], label='Unified Momentum')
ax[1,1].plot(ws_cop, cop, 'grey')
ax[1,1].set_ylim([0,0.65])
ax[1,1].grid(True,color = "grey", linewidth = "0.25")

ax[1,0].set_xlabel('Wind speed [m/s]')
ax[1,1].set_xlabel('Wind speed [m/s]')
# Out:
# Text(0.5, 0, 'Wind speed [m/s]')

# %% [markdown]
# # IEA 15 MW

# %%
from MITRotor import IEA15MW

# %%
# Initialize rotor with increased radial resolution.
rotor = IEA15MW()

ClassMom = BEM(rotor=rotor, geometry=BEMGeometry(Nr=99, Ntheta=360), aerodynamic_model=KraghAerodynamics(), tiploss_model=NoTipLoss(), momentum_model=ClassicalMomentum(), tangential_induction_model=NoTangentialInduction())

ConstInd = BEM(rotor=rotor, geometry=BEMGeometry(Nr=99, Ntheta=360), aerodynamic_model=KraghAerodynamics(), tiploss_model=NoTipLoss(), momentum_model=ConstantInduction(), tangential_induction_model=NoTangentialInduction())

MadseMom = BEM(rotor=rotor, geometry=BEMGeometry(Nr=99, Ntheta=360), aerodynamic_model=KraghAerodynamics(), tiploss_model=NoTipLoss(), momentum_model=MadsenMomentum(), tangential_induction_model=NoTangentialInduction())

UnifiMom = BEM(rotor=rotor, geometry=BEMGeometry(Nr=99, Ntheta=360), aerodynamic_model=KraghAerodynamics(), tiploss_model=NoTipLoss(), momentum_model=UnifiedMomentum(), tangential_induction_model=NoTangentialInduction())

# %%
ws_pow = np.array([3.03,3.36,3.58,3.85,4.06,4.27,4.52,4.70,4.80,4.90,5.00,5.10,5.20,5.30,5.40,5.50,5.60,5.70,5.80,5.90,6.00,6.10,6.20,6.30,6.40,6.50,6.60,6.70,6.80,6.90,7.00,7.10,7.20,7.30,7.40,7.50,7.60,7.70,7.80,7.90,8.00,8.10,8.20,8.30,8.40,8.50,8.60,8.70,8.80,8.90,9.00,9.10,9.20,9.30,9.40,9.50,9.60,9.70,9.80,9.90,10.00,10.10,10.20,10.30,10.40,10.50,10.60,10.70,10.80,10.90,11.00,11.10,11.20,11.30,11.40,11.50,11.60,11.70,11.80,11.90,12.00,12.10,12.20,12.30,12.40,12.50,12.60,12.70,12.80,12.90,13.00,13.10,13.20,13.30,13.40,13.50,13.60,13.70,13.80,13.90,14.00,14.10,14.20,14.30,14.40,14.50,14.60,14.70,14.80,14.90,15.00,15.10,15.20,15.30,15.40,15.50,15.60,15.70,15.80,15.90,16.00,16.10,16.20,16.30,16.40,16.50,16.60,16.70,16.80,16.90,17.00,17.10,17.20,17.30,17.40,17.50,17.60,17.70,17.80,17.90,18.00,18.10,18.20,18.30,18.40,18.50,18.60,18.70,18.80,18.90,19.00,19.10,19.20,19.30,19.40,19.50,19.60,19.70,19.80,19.90,20.00,20.10,20.20,20.30,20.40,20.50,20.60,20.70,20.80,20.90,21.00,21.10,21.20,21.30,21.40,21.50,21.60,21.70,21.80,21.90,22.00,22.10,22.20,22.30,22.40,22.50,22.60,22.70,22.80,22.90,23.00,23.10,23.20,23.30,23.40,23.50,23.60,23.70,23.80,23.90,24.00,24.10,24.20,24.30,24.40,24.50,24.60,24.70,24.80,24.90, 25])
7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5576,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5576,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310,7.5310])

# %%
f_rpm = interp1d(ws_rpm, rpm, kind='linear')
f_pit = interp1d(ws_pit, pitch, kind='linear')

# %%
ws_ref = np.linspace(6, 25, 50)

# %%
ClassMom_cot = np.zeros_like(ws_ref)
ClassMom_cop = np.zeros_like(ws_ref)
ClassMom_P   = np.zeros_like(ws_ref)
ClassMom_T   = np.zeros_like(ws_ref)

ConstInd_cot = np.zeros_like(ws_ref)
ConstInd_cop = np.zeros_like(ws_ref)
ConstInd_P   = np.zeros_like(ws_ref)
ConstInd_T   = np.zeros_like(ws_ref)

MadseMom_cot = np.zeros_like(ws_ref)
MadseMom_cop = np.zeros_like(ws_ref)
MadseMom_P   = np.zeros_like(ws_ref)
MadseMom_T   = np.zeros_like(ws_ref)

UnifiMom_cot = np.zeros_like(ws_ref)
UnifiMom_cop = np.zeros_like(ws_ref)
UnifiMom_P   = np.zeros_like(ws_ref)
UnifiMom_T   = np.zeros_like(ws_ref)

# %%
for i in range(len(ws_ref)):
    pitch, tsr, yaw = np.deg2rad(f_pit(ws_ref[i])), f_rpm(ws_ref[i]) * 2 * np.pi * rotor.R / 60 / ws_ref[i], np.deg2rad(0.0)
    ClassMomSol = ClassMom(pitch, tsr, yaw, v_inf=ws_ref[i])
    ConstIndSol = ConstInd(pitch, tsr, yaw, v_inf=ws_ref[i])
    MadseMomSol = MadseMom(pitch, tsr, yaw, v_inf=ws_ref[i])
    UnifiMomSol = UnifiMom(pitch, tsr, yaw, v_inf=ws_ref[i])

    # print('Classical Momentum')
    ClassMom_cot[i] = ClassMomSol.Ct()
    ClassMom_cop[i] = ClassMomSol.Cp()
    ClassMom_P[i]   = ClassMomSol.power()
    ClassMom_T[i]   = ClassMomSol.thrust()

    # print('Constant Induction')
    ConstInd_cot[i] = ConstIndSol.Ct()
    ConstInd_cop[i] = ConstIndSol.Cp()
    ConstInd_P[i]   = ConstIndSol.power()
    ConstInd_T[i]   = ConstIndSol.thrust()

    # print('Madsen Momentum')
    MadseMom_cot[i] = MadseMomSol.Ct()
    MadseMom_cop[i] = MadseMomSol.Cp()
    MadseMom_P[i]   = MadseMomSol.power()
    MadseMom_T[i]   = MadseMomSol.thrust()

    UnifiMom_cot[i] = UnifiMomSol.Ct()
    UnifiMom_cop[i] = UnifiMomSol.Cp()
    UnifiMom_P[i]   = UnifiMomSol.power()
    UnifiMom_T[i]   = UnifiMomSol.thrust()
# Out:
# /home1/09909/smata/miniconda3/envs/mitrotor/lib/python3.10/site-packages/UnifiedMomentumModel/Momentum.py:109: RuntimeWarning: invalid value encountered in sqrt
#   e_a = 1 - np.sqrt(1 - u4**2 - v4**2) / (np.sqrt(Ctprime) * np.cos(yaw)) - a
# /home1/09909/smata/miniconda3/envs/mitrotor/lib/python3.10/site-packages/UnifiedMomentumModel/Utilities/FixedPointIteration.py:56: RuntimeWarning: All-NaN axis encountered
#   max_resid = [np.nanmax(np.abs(_r)) for _r in residuals]

# %%
fig, ax = plt.subplots(2, 2, figsize=(18, 9), sharex=True)

ax[0,0].set_ylabel('Thrust [kN]')
# ax[0,0].plot(ws_ref, ConstInd_cot*0.5*1.225*np.pi*(rotor.R**2)*(ws_ref**2)/1000, color=sns.color_palette()[0], label='Constant Induction ($a=1/3$)')
ax[0,0].plot(ws_ref, ClassMom_T/1000, color=sns.color_palette()[2], label='Classical Momentum')
ax[0,0].plot(ws_ref, MadseMom_T/1000, color=sns.color_palette()[3], label='Madsen Momentum')
ax[0,0].plot(ws_ref, UnifiMom_T/1000, color=sns.color_palette()[4], label='Unified Momentum')
ax[0,0].plot(ws_thr, thrust, 'grey', label='Reference')
ax[0,0].legend(loc='upper right', framealpha=1)
ax[0,0].set_ylim([0,3000])
ax[0,0].set_xlim([0,25])
ax[0,0].grid(True,color = "grey", linewidth = "0.25")

ax[0,1].set_ylabel('Power [kW]')
# ax[0,1].plot(ws_ref, ConstInd_cop*0.5*1.225*np.pi*(rotor.R**2)*(ws_ref**3)/1000, color=sns.color_palette()[0], label='Constant Induction ($a=1/3$)')
ax[0,1].plot(ws_ref, ClassMom_P/1000, color=sns.color_palette()[2], label='Classical Momentum')
ax[0,1].plot(ws_ref, MadseMom_P/1000, color=sns.color_palette()[3], label='Madsen Momentum')
ax[0,1].plot(ws_ref, UnifiMom_P/1000, color=sns.color_palette()[4], label='Unified Momentum')
ax[0,1].plot(ws_pow, power, 'grey', label='Reference')
ax[0,1].set_ylim([0,27000])
ax[0,1].grid(True,color = "grey", linewidth = "0.25")

ax[1,0].set_ylabel('$C_T$ [-]')
# ax[1,0].plot(ws_ref, ConstInd_cot, color=sns.color_palette()[0], label='Constant Induction ($a=1/3$)')
ax[1,0].plot(ws_ref, ClassMom_cot, color=sns.color_palette()[2], label='Classical Momentum')
ax[1,0].plot(ws_ref, MadseMom_cot, color=sns.color_palette()[3], label='Madsen Momentum')
ax[1,0].plot(ws_ref, UnifiMom_cot, color=sns.color_palette()[4], label='Unified Momentum')
ax[1,0].plot(ws_cot, cot, 'grey')
# ax[1,0].legend()
ax[1,0].set_ylim([0,1.05])
ax[1,0].grid(True,color = "grey", linewidth = "0.25")

ax[1,1].set_ylabel('$C_P$ [-]')
# ax[1,1].plot(ws_ref, ConstInd_cop, color=sns.color_palette()[0], label='Constant Induction ($a=1/3$)')
ax[1,1].plot(ws_ref, ClassMom_cop, color=sns.color_palette()[2], label='Classical Momentum')
ax[1,1].plot(ws_ref, MadseMom_cop, color=sns.color_palette()[3], label='Madsen Momentum')
ax[1,1].plot(ws_ref, UnifiMom_cop, color=sns.color_palette()[4], label='Unified Momentum')
ax[1,1].plot(ws_cop, cop, 'grey')
ax[1,1].set_ylim([0,0.65])
ax[1,1].grid(True,color = "grey", linewidth = "0.25")

ax[1,0].set_xlabel('Wind speed [m/s]')
ax[1,1].set_xlabel('Wind speed [m/s]')
# Out:
# Text(0.5, 0, 'Wind speed [m/s]')
